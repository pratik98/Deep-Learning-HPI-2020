# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from datetime import datetime
import pandas as pd
plt.style.use('ggplot')
import tensorflow as tf
keras = tf.keras

# %% [markdown]
# # **DATA PREPARATION**

# %% [markdown]
# ## Read dataset and Initial Processing

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mdrkb/avocado-prices/master/avocado_updated.csv', 
                 parse_dates=['Date'])

# %% [markdown]
# ## There are 5 main regions and 48 sub regions

# %%
all_regions = df.region.unique()

regions = ['West', 'Northeast', 'Southeast', 'SouthCentral','Midsouth']

total_US = ['TotalUS']

sub_regions = []
for reg in df.region.unique():
    if reg not in regions and reg not in total_US:
        sub_regions.append(reg)

print("5 Regions: ", regions, "\r\n")
print("48 Sub regions", sub_regions)
# Out:
# 5 Regions:  ['West', 'Northeast', 'Southeast', 'SouthCentral', 'Midsouth']
#
# 48 Sub regions ['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston', 'BuffaloRochester', 'California', 'Charlotte', 'Chicago', 'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver', 'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton', 'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville', 'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale', 'Nashville', 'NewOrleansMobile', 'NewYork', 'NorthernNewEngland', 'Orlando', 'Philadelphia', 'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland', 'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento', 'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina', 'Spokane', 'StLouis', 'Syracuse', 'Tampa', 'WestTexNewMexico']

# %% [markdown]
# ## Filter Dataset to get Average Prices of **"organic"** avocado for all 5 regions

# %%
avocado_type = list(df["type"].unique())
print("Avocado Types: ", avocado_type)

region_df = df[df["region"].isin(regions)]
region_df = region_df[region_df["type"]=="organic"][["Date","AveragePrice","region"]]
region_df = region_df.sort_values(["region","Date"])
region_df = region_df.set_index("Date")

region_df_with_region = pd.concat([region_df,pd.get_dummies(region_df.region)], axis=1)
# Out:
# Avocado Types:  ['conventional', 'organic']

# %% [markdown]
# ## Splitting dataset in Train and Test, for each of 5 regions, 80% of data is taken for training.
# ## Preparing data for supervised learning with window size 10.

# %%
def sequential_window_dataset(series, window_size,shift_val=1):
    ds = tf.data.Dataset.from_tensor_slices(series,)
    ds = ds.window(window_size + 1, shift=shift_val, drop_remainder=True)
    ds = ds.flat_map(lambda window: window.batch(window_size + 1))
    ds = ds.map(lambda window: (window[:-1], window[1:]))
    return ds.batch(1).prefetch(1)


train_dataset_list = []
test_dataset_list = []
forecast_df = region_df_with_region[0:0]

for reg in regions:
    reg_df = region_df_with_region[region_df_with_region.region == reg]
    train_size = int(np.floor(reg_df.AveragePrice.count() * 0.8)) 
    reg_train_df = reg_df[:train_size]
    reg_test_df = reg_df[train_size:]
    reg_train_series = reg_train_df.drop(columns=["region"]).values
    reg_test_series = reg_test_df.drop(columns=["region"]).values
    
    reg_train_ds = sequential_window_dataset(reg_train_series,10,shift_val=2)
    train_dataset_list.append(reg_train_ds)
    reg_test_ds = sequential_window_dataset(reg_test_series,10,shift_val=5)
    test_dataset_list.append(reg_test_ds)
    
    forecast_df = forecast_df.append(reg_test_df)

# %%
test_dataset = None
train_dataset = None

count=0
for i in train_dataset_list:
    if count == 0:
        train_dataset = i
    else:
        train_dataset = train_dataset.concatenate(i)
    count = count + 1

count=0 
for i in test_dataset_list:
    if count == 0:
        test_dataset = i
    else:
        test_dataset = test_dataset.concatenate(i)
    count = count + 1

# %% [markdown]
# ## Plotting the Average Prices for 5 regions

# %%
reg_names = list(region_df.region.unique())[:4]
df_list = []
for reg_name in reg_names:
    df_list.append(region_df[region_df.region==reg_name][["AveragePrice"]])
    
nrow=2
ncol=2
fig, axes = plt.subplots(nrow, ncol)
count=0
for r in range(nrow):
    for c in range(ncol):
        axi = df_list[count].plot(ax=axes[r,c],title=reg_names[count],figsize=(15,8))
        axi.set_ylabel("Avocado Average Price")
        axi.set_xlabel("Year")
        plt.tight_layout()
        count = count+1

# %% [markdown]
# # **LSTM MODEL**

# %% [markdown]
# ## Learning rate optimization

# %%
lstm_model = keras.models.Sequential([
  keras.layers.LSTM(30, return_sequences=True,batch_input_shape=[1,None,6]),
  keras.layers.Dense(6),
  keras.layers.Lambda(lambda x: x * 200.0)
])

lr_schedule = keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-06 * 10**(epoch / 10))

optimizer = keras.optimizers.Adam(lr=1e-6)
lstm_model.compile(loss='mse',
              optimizer=optimizer,
              metrics=["mae","mse"])


lstm_lr_history = lstm_model.fit(train_dataset, epochs=50,
                    callbacks=[lr_schedule])
# Out:
# Epoch 1/50
# 520/520 [==============================] - 3s 6ms/step - loss: 871.3958 - mae: 22.1580 - mse: 871.3955 - lr: 1.0000e-06
# Epoch 2/50
# 520/520 [==============================] - 3s 6ms/step - loss: 817.7366 - mae: 21.3767 - mse: 817.7368 - lr: 1.2589e-06
# Epoch 3/50
# 520/520 [==============================] - 3s 6ms/step - loss: 753.3441 - mae: 20.4456 - mse: 753.3444 - lr: 1.5849e-06
# Epoch 4/50
# 520/520 [==============================] - 3s 6ms/step - loss: 681.0707 - mae: 19.3778 - mse: 681.0706 - lr: 1.9953e-06
# Epoch 5/50
# 520/520 [==============================] - 3s 6ms/step - loss: 602.7466 - mae: 18.1777 - mse: 602.7466 - lr: 2.5119e-06
# Epoch 6/50
# 520/520 [==============================] - 3s 6ms/step - loss: 520.7083 - mae: 16.8610 - mse: 520.7084 - lr: 3.1623e-06
# Epoch 7/50
# 520/520 [==============================] - 3s 6ms/step - loss: 437.8287 - mae: 15.4461 - mse: 437.8287 - lr: 3.9811e-06
# Epoch 8/50
# 520/520 [==============================] - 3s 6ms/step - loss: 357.2135 - mae: 13.9571 - mse: 357.2135 - lr: 5.0119e-06
# Epoch 9/50
# 520/520 [==============================] - 3s 6ms/step - loss: 281.8459 - mae: 12.4320 - mse: 281.8459 - lr: 6.3096e-06
# Epoch 10/50
# 520/520 [==============================] - 3s 6ms/step - loss: 214.3928 - mae: 10.8960 - mse: 214.3928 - lr: 7.9433e-06
# Epoch 11/50
# 520/520 [==============================] - 3s 6ms/step - loss: 156.9595 - mae: 9.3759 - mse: 156.9596 - lr: 1.0000e-05
# Epoch 12/50
# 520/520 [==============================] - 3s 6ms/step - loss: 110.4467 - mae: 7.8959 - mse: 110.4467 - lr: 1.2589e-05
# Epoch 13/50
# 520/520 [==============================] - 3s 6ms/step - loss: 74.1322 - mae: 6.5198 - mse: 74.1321 - lr: 1.5849e-05
# Epoch 14/50
# 520/520 [==============================] - 3s 6ms/step - loss: 46.7091 - mae: 5.2076 - mse: 46.7092 - lr: 1.9953e-05
# Epoch 15/50
# 520/520 [==============================] - 3s 6ms/step - loss: 27.6122 - mae: 3.9721 - mse: 27.6122 - lr: 2.5119e-05
# Epoch 16/50
# 520/520 [==============================] - 3s 6ms/step - loss: 16.1391 - mae: 2.9690 - mse: 16.1391 - lr: 3.1623e-05
# Epoch 17/50
# 520/520 [==============================] - 3s 6ms/step - loss: 10.1603 - mae: 2.3120 - mse: 10.1603 - lr: 3.9811e-05
# Epoch 18/50
# 520/520 [==============================] - 3s 6ms/step - loss: 7.0288 - mae: 1.9125 - mse: 7.0288 - lr: 5.0119e-05
# Epoch 19/50
# 520/520 [==============================] - 3s 6ms/step - loss: 5.0528 - mae: 1.6287 - mse: 5.0528 - lr: 6.3096e-05
# Epoch 20/50
# 520/520 [==============================] - 3s 6ms/step - loss: 3.5575 - mae: 1.3804 - mse: 3.5575 - lr: 7.9433e-05
# Epoch 21/50
# 520/520 [==============================] - 4s 7ms/step - loss: 2.3996 - mae: 1.1429 - mse: 2.3996 - lr: 1.0000e-04
# Epoch 22/50
# 520/520 [==============================] - 3s 6ms/step - loss: 1.6068 - mae: 0.9356 - mse: 1.6068 - lr: 1.2589e-04
# Epoch 23/50
# 520/520 [==============================] - 3s 6ms/step - loss: 1.1206 - mae: 0.7793 - mse: 1.1206 - lr: 1.5849e-04
# Epoch 24/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.7542 - mae: 0.6320 - mse: 0.7542 - lr: 1.9953e-04
# Epoch 25/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.5604 - mae: 0.5406 - mse: 0.5604 - lr: 2.5119e-04
# Epoch 26/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.5017 - mae: 0.5144 - mse: 0.5017 - lr: 3.1623e-04
# Epoch 27/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.5169 - mae: 0.5225 - mse: 0.5169 - lr: 3.9811e-04
# Epoch 28/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.4978 - mae: 0.5027 - mse: 0.4978 - lr: 5.0119e-04
# Epoch 29/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.5361 - mae: 0.5062 - mse: 0.5361 - lr: 6.3096e-04
# Epoch 30/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.6006 - mae: 0.5284 - mse: 0.6006 - lr: 7.9433e-04
# Epoch 31/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.4931 - mae: 0.4755 - mse: 0.4931 - lr: 0.0010
# Epoch 32/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.4660 - mae: 0.4665 - mse: 0.4660 - lr: 0.0013
# Epoch 33/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.4358 - mae: 0.4561 - mse: 0.4358 - lr: 0.0016
# Epoch 34/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.3581 - mae: 0.4070 - mse: 0.3581 - lr: 0.0020
# Epoch 35/50
# 520/520 [==============================] - 3s 7ms/step - loss: 0.2365 - mae: 0.3299 - mse: 0.2365 - lr: 0.0025
# Epoch 36/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.1905 - mae: 0.2848 - mse: 0.1905 - lr: 0.0032
# Epoch 37/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.1644 - mae: 0.2548 - mse: 0.1644 - lr: 0.0040
# Epoch 38/50
# 520/520 [==============================] - 3s 7ms/step - loss: 0.1275 - mae: 0.2154 - mse: 0.1275 - lr: 0.0050
# Epoch 39/50
# 520/520 [==============================] - 3s 7ms/step - loss: 0.0797 - mae: 0.1698 - mse: 0.0797 - lr: 0.0063
# Epoch 40/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.0596 - mae: 0.1457 - mse: 0.0596 - lr: 0.0079
# Epoch 41/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.0753 - mae: 0.1479 - mse: 0.0753 - lr: 0.0100
# Epoch 42/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.0354 - mae: 0.1078 - mse: 0.0354 - lr: 0.0126
# Epoch 43/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.0789 - mae: 0.1328 - mse: 0.0789 - lr: 0.0158
# Epoch 44/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.0331 - mae: 0.1028 - mse: 0.0331 - lr: 0.0200
# Epoch 45/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.0567 - mae: 0.1233 - mse: 0.0567 - lr: 0.0251
# Epoch 46/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.0773 - mae: 0.1379 - mse: 0.0773 - lr: 0.0316
# Epoch 47/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.1292 - mae: 0.1457 - mse: 0.1292 - lr: 0.0398
# Epoch 48/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.1616 - mae: 0.1627 - mse: 0.1616 - lr: 0.0501
# Epoch 49/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.2677 - mae: 0.2001 - mse: 0.2677 - lr: 0.0631
# Epoch 50/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.5555 - mae: 0.2602 - mse: 0.5555 - lr: 0.0794

# %% [markdown]
# ##Plotting Loss vs Learning to find optimal learning rate

# %%
plt.semilogx(lstm_lr_history.history["lr"], lstm_lr_history.history["loss"])
plt.xlabel("Learning rate")
plt.ylabel("Loss")
plt.axis([1e-6, 1e-1, 0, 2])
plt.title("LSTM Loss vs Learning Rate")
plt.show()

# %% [markdown]
# ## Training the LSTM model

# %%
lstm_model = keras.models.Sequential([
  keras.layers.LSTM(30,batch_input_shape=[1,None,6],name="first",return_sequences=True),
  keras.layers.Dense(6,name="third")
])

optimizer = keras.optimizers.Adam(lr=1e-2)

lstm_model.compile(loss='mse',
              optimizer=optimizer,
              metrics=["mse","mae"])

model_checkpoint = keras.callbacks.ModelCheckpoint(
    "lstm_checkpoint", save_best_only=True)

early_stopping = keras.callbacks.EarlyStopping(patience=30)

lstm_history = lstm_model.fit(train_dataset, epochs=50,
          validation_data=test_dataset ,
          callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/50
#     519/Unknown - 4s 7ms/step - loss: 0.0286 - mse: 0.0286 - mae: 0.0790WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 20ms/step - loss: 0.0285 - mse: 0.0285 - mae: 0.0789 - val_loss: 0.2655 - val_mse: 0.2655 - val_mae: 0.3107
# Epoch 2/50
# 518/520 [============================>.] - ETA: 0s - loss: 0.0326 - mse: 0.0326 - mae: 0.0856INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 18ms/step - loss: 0.0325 - mse: 0.0325 - mae: 0.0854 - val_loss: 0.2169 - val_mse: 0.2169 - val_mae: 0.3169
# Epoch 3/50
# 518/520 [============================>.] - ETA: 0s - loss: 0.0276 - mse: 0.0276 - mae: 0.0828INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 19ms/step - loss: 0.0275 - mse: 0.0275 - mae: 0.0827 - val_loss: 0.1327 - val_mse: 0.1327 - val_mae: 0.2633
# Epoch 4/50
# 517/520 [============================>.] - ETA: 0s - loss: 0.0208 - mse: 0.0208 - mae: 0.0753INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 20ms/step - loss: 0.0207 - mse: 0.0207 - mae: 0.0751 - val_loss: 0.0838 - val_mse: 0.0838 - val_mae: 0.2110
# Epoch 5/50
# 513/520 [============================>.] - ETA: 0s - loss: 0.0161 - mse: 0.0161 - mae: 0.0663INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 19ms/step - loss: 0.0160 - mse: 0.0160 - mae: 0.0660 - val_loss: 0.0417 - val_mse: 0.0417 - val_mae: 0.1502
# Epoch 6/50
# 512/520 [============================>.] - ETA: 0s - loss: 0.0131 - mse: 0.0131 - mae: 0.0589INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 9s 18ms/step - loss: 0.0129 - mse: 0.0129 - mae: 0.0586 - val_loss: 0.0268 - val_mse: 0.0268 - val_mae: 0.1237
# Epoch 7/50
# 517/520 [============================>.] - ETA: 0s - loss: 0.0116 - mse: 0.0116 - mae: 0.0537INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 9s 18ms/step - loss: 0.0116 - mse: 0.0116 - mae: 0.0536 - val_loss: 0.0222 - val_mse: 0.0222 - val_mae: 0.1105
# Epoch 8/50
# 516/520 [============================>.] - ETA: 0s - loss: 0.0108 - mse: 0.0108 - mae: 0.0510INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 9s 18ms/step - loss: 0.0107 - mse: 0.0107 - mae: 0.0508 - val_loss: 0.0204 - val_mse: 0.0204 - val_mae: 0.1054
# Epoch 9/50
# 518/520 [============================>.] - ETA: 0s - loss: 0.0100 - mse: 0.0100 - mae: 0.0490INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 9s 18ms/step - loss: 0.0100 - mse: 0.0100 - mae: 0.0489 - val_loss: 0.0187 - val_mse: 0.0187 - val_mae: 0.1011
# Epoch 10/50
# 515/520 [============================>.] - ETA: 0s - loss: 0.0091 - mse: 0.0091 - mae: 0.0477INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 9s 18ms/step - loss: 0.0091 - mse: 0.0091 - mae: 0.0475 - val_loss: 0.0180 - val_mse: 0.0180 - val_mae: 0.0998
# Epoch 11/50
# 517/520 [============================>.] - ETA: 0s - loss: 0.0081 - mse: 0.0081 - mae: 0.0456INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 9s 18ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0454 - val_loss: 0.0158 - val_mse: 0.0158 - val_mae: 0.0922
# Epoch 12/50
# 518/520 [============================>.] - ETA: 0s - loss: 0.0072 - mse: 0.0072 - mae: 0.0433INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 9s 18ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0433 - val_loss: 0.0133 - val_mse: 0.0133 - val_mae: 0.0833
# Epoch 13/50
# 518/520 [============================>.] - ETA: 0s - loss: 0.0065 - mse: 0.0065 - mae: 0.0412INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 9s 18ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0412 - val_loss: 0.0123 - val_mse: 0.0123 - val_mae: 0.0817
# Epoch 14/50
# 513/520 [============================>.] - ETA: 0s - loss: 0.0060 - mse: 0.0060 - mae: 0.0398INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 9s 18ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0396 - val_loss: 0.0119 - val_mse: 0.0119 - val_mae: 0.0822
# Epoch 15/50
# 513/520 [============================>.] - ETA: 0s - loss: 0.0057 - mse: 0.0057 - mae: 0.0387INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 19ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0385 - val_loss: 0.0117 - val_mse: 0.0117 - val_mae: 0.0827
# Epoch 16/50
# 520/520 [==============================] - 4s 7ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0380 - val_loss: 0.0117 - val_mse: 0.0117 - val_mae: 0.0811
# Epoch 17/50
# 519/520 [============================>.] - ETA: 0s - loss: 0.0054 - mse: 0.0054 - mae: 0.0374INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 20ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0373 - val_loss: 0.0111 - val_mse: 0.0111 - val_mae: 0.0780
# Epoch 18/50
# 520/520 [==============================] - 4s 7ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0371 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0782
# Epoch 19/50
# 520/520 [==============================] - 4s 7ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0370 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0768
# Epoch 20/50
# 516/520 [============================>.] - ETA: 0s - loss: 0.0051 - mse: 0.0051 - mae: 0.0366INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 19ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0365 - val_loss: 0.0106 - val_mse: 0.0106 - val_mae: 0.0744
# Epoch 21/50
# 514/520 [============================>.] - ETA: 0s - loss: 0.0051 - mse: 0.0051 - mae: 0.0363INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 19ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0362 - val_loss: 0.0103 - val_mse: 0.0103 - val_mae: 0.0726
# Epoch 22/50
# 519/520 [============================>.] - ETA: 0s - loss: 0.0050 - mse: 0.0050 - mae: 0.0358INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 9s 18ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0358 - val_loss: 0.0098 - val_mse: 0.0098 - val_mae: 0.0700
# Epoch 23/50
# 519/520 [============================>.] - ETA: 0s - loss: 0.0049 - mse: 0.0049 - mae: 0.0355INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 18ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0355 - val_loss: 0.0096 - val_mse: 0.0096 - val_mae: 0.0685
# Epoch 24/50
# 512/520 [============================>.] - ETA: 0s - loss: 0.0049 - mse: 0.0049 - mae: 0.0353INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 9s 18ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0351 - val_loss: 0.0093 - val_mse: 0.0093 - val_mae: 0.0675
# Epoch 25/50
# 518/520 [============================>.] - ETA: 0s - loss: 0.0048 - mse: 0.0048 - mae: 0.0349INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 9s 18ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0349 - val_loss: 0.0093 - val_mse: 0.0093 - val_mae: 0.0674
# Epoch 26/50
# 519/520 [============================>.] - ETA: 0s - loss: 0.0048 - mse: 0.0048 - mae: 0.0347INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 9s 18ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0346 - val_loss: 0.0090 - val_mse: 0.0090 - val_mae: 0.0668
# Epoch 27/50
# 516/520 [============================>.] - ETA: 0s - loss: 0.0046 - mse: 0.0046 - mae: 0.0341INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 18ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0340 - val_loss: 0.0086 - val_mse: 0.0086 - val_mae: 0.0654
# Epoch 28/50
# 515/520 [============================>.] - ETA: 0s - loss: 0.0046 - mse: 0.0046 - mae: 0.0340INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 18ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0339 - val_loss: 0.0084 - val_mse: 0.0084 - val_mae: 0.0646
# Epoch 29/50
# 520/520 [==============================] - 3s 7ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0336 - val_loss: 0.0084 - val_mse: 0.0084 - val_mae: 0.0652
# Epoch 30/50
# 514/520 [============================>.] - ETA: 0s - loss: 0.0045 - mse: 0.0045 - mae: 0.0337INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 19ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0336 - val_loss: 0.0080 - val_mse: 0.0080 - val_mae: 0.0632
# Epoch 31/50
# 520/520 [==============================] - 4s 7ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0337 - val_loss: 0.0084 - val_mse: 0.0084 - val_mae: 0.0650
# Epoch 32/50
# 520/520 [==============================] - 4s 7ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0342 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0653
# Epoch 33/50
# 516/520 [============================>.] - ETA: 0s - loss: 0.0045 - mse: 0.0045 - mae: 0.0343INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 9s 18ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0342 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0629
# Epoch 34/50
# 513/520 [============================>.] - ETA: 0s - loss: 0.0044 - mse: 0.0044 - mae: 0.0341INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 11s 21ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0339 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0605
# Epoch 35/50
# 520/520 [==============================] - 3s 6ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0330 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0631
# Epoch 36/50
# 515/520 [============================>.] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0329INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 18ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0328 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0579
# Epoch 37/50
# 520/520 [==============================] - 4s 7ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0322 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0577
# Epoch 38/50
# 518/520 [============================>.] - ETA: 0s - loss: 0.0041 - mse: 0.0041 - mae: 0.0314INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 20ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0314 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0566
# Epoch 39/50
# 516/520 [============================>.] - ETA: 0s - loss: 0.0042 - mse: 0.0042 - mae: 0.0313INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 19ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0312 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0562
# Epoch 40/50
# 520/520 [==============================] - 4s 8ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0305 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0577
# Epoch 41/50
# 520/520 [==============================] - 4s 7ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0304 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0536
# Epoch 42/50
# 514/520 [============================>.] - ETA: 0s - loss: 0.0041 - mse: 0.0041 - mae: 0.0297INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 19ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0296 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0545
# Epoch 43/50
# 515/520 [============================>.] - ETA: 0s - loss: 0.0040 - mse: 0.0040 - mae: 0.0297INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 19ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0296 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0528
# Epoch 44/50
# 520/520 [==============================] - 4s 7ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0295 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0541
# Epoch 45/50
# 515/520 [============================>.] - ETA: 0s - loss: 0.0038 - mse: 0.0038 - mae: 0.0287INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 19ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0286 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0514
# Epoch 46/50
# 513/520 [============================>.] - ETA: 0s - loss: 0.0039 - mse: 0.0039 - mae: 0.0287INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 11s 21ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0286 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0514
# Epoch 47/50
# 519/520 [============================>.] - ETA: 0s - loss: 0.0038 - mse: 0.0038 - mae: 0.0285INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 11s 21ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0285 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0503
# Epoch 48/50
# 514/520 [============================>.] - ETA: 0s - loss: 0.0039 - mse: 0.0039 - mae: 0.0283INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 10s 20ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0282 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0501
# Epoch 49/50
# 519/520 [============================>.] - ETA: 0s - loss: 0.0038 - mse: 0.0038 - mae: 0.0277INFO:tensorflow:Assets written to: lstm_checkpoint/assets
# 520/520 [==============================] - 11s 20ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0277 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0479
# Epoch 50/50
# 520/520 [==============================] - 4s 7ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0276 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0492

# %% [markdown]
# ## Plotting Validation Loss and Training Loss for LSTM

# %%
plt.plot(lstm_history.history["loss"], label="Traning Loss")
plt.plot(lstm_history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
# plt.savefig("training_val_loss.jpg")
plt.show()

# %% [markdown]
# ##Choose the **model** from checkpoints

# %%
lstm_model = keras.models.load_model("lstm_checkpoint")

# %% [markdown]
# ## Model evaluation

# %%
def get_metrics(test_set):
    metrics = lstm_model.metrics_names
    metric_val = lstm_model.evaluate(test_set)
    metric_string = "\r\n  Loss is - " + str(metric_val[0]) + ",\r\n  Mean Absolute Error is  -  " +  str(metric_val[2]) + \
    ",\r\n  Mean Squared Error is  -  " + str(metric_val[1]) \
    + ",\r\n  Root Mean Squared Error is  -  "       +   str(np.sqrt(metric_val[1]))
    return metric_string

# Printing metrics for 2 regions out of 5
forecast_regions = list(forecast_df.region.unique())
for each_region in forecast_regions:
  f_df = forecast_df[forecast_df.region==each_region]
  f_series = f_df.drop("region",axis=1).values
  f_ds = sequential_window_dataset(f_series,13,shift_val=13)
  m = get_metrics(f_ds)
  print("For Region - ",each_region,m)
  print("\r\n")
# Out:
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0523
# For Region -  West
#   Loss is - 0.0055844783782958984,
#   Mean Absolute Error is  -  0.052259452641010284,
#   Mean Squared Error is  -  0.0055844783782958984,
#   Root Mean Squared Error is  -  0.07472936757591288
#
#
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0565
# For Region -  Northeast
#   Loss is - 0.006298842374235392,
#   Mean Absolute Error is  -  0.05647963657975197,
#   Mean Squared Error is  -  0.006298842374235392,
#   Root Mean Squared Error is  -  0.07936524664004636
#
#
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0675
# For Region -  Southeast
#   Loss is - 0.007570136804133654,
#   Mean Absolute Error is  -  0.06750299036502838,
#   Mean Squared Error is  -  0.007570137269794941,
#   Root Mean Squared Error is  -  0.08700653578780701
#
#
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0400
# For Region -  SouthCentral
#   Loss is - 0.0029391678981482983,
#   Mean Absolute Error is  -  0.04004167765378952,
#   Mean Squared Error is  -  0.0029391678981482983,
#   Root Mean Squared Error is  -  0.05421409316910408
#
#
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0196
# For Region -  Midsouth
#   Loss is - 0.00209566461853683,
#   Mean Absolute Error is  -  0.019619736820459366,
#   Mean Squared Error is  -  0.00209566461853683,
#   Root Mean Squared Error is  -  0.04577842962069396

# %% [markdown]
# ## LSTM: Predict and plot the prediction for few regions

# %%
def plot_lstm_series(time, series,title, format="-", start=0, end=None, label=None):
    plt.plot(time[start:end], series[start:end], format, label=label)
    plt.xlabel("Time")
    plt.ylabel("Average Price Value")
    plt.legend(fontsize=15)
    plt.title(title)

# Choosing 2 regions out of 5
forecast_regions = list(forecast_df.region.unique())

# Predicting and plotting 2 regions
for each_region in forecast_regions:
  predict_df = forecast_df[forecast_df.region==each_region]
  predict_series = predict_df.drop(columns=["region"]).values
  predict_series = predict_series.reshape(1,len(f_series),6)
  LSTM_forecast = lstm_model.predict(predict_series)
  LSTM_forecast = LSTM_forecast[0,:,0]
  
  plt.figure(figsize=(10, 6))
  plot_lstm_series(list(range(0,len(predict_series[0,:,0]))), list(predict_series[0,:,0]),title=each_region,label="Truth value")
  plot_lstm_series(list(range(0,len(predict_series[0,:,0]))), LSTM_forecast,title=each_region,label="Prediction")
  plt.show()
